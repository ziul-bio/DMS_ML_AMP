# %% [markdown]
# ## Machine Learning applied to identify Selective Antimicobrial Peptides
#
# In this notebook is described all the procedure used to train and test the Selectivity model.

# %%
import os
import torch
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVR

from sklearn.decomposition import PCA
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression

import joblib
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, LeaveOneOut

import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='seaborn.axisgrid', message='The figure layout has changed to tight')

# %%
# This function wil convert the undefined MIC values to 100.
def convert_mic(mic_value):
    if type(mic_value) == str and mic_value.startswith('>'):
        mic_value = float(mic_value.replace('>', ''))
        v = 100
        return v
    else:
        return float(mic_value)

convert_mic('>64')
# Out:
# 100

# %%
# Load meta data
meta_data = pd.read_excel("data/Cumulative_Peptide_data_PG1_v01.2.xlsx")
meta_data["MBC"] = [convert_mic(x) for x in meta_data["MBC"]]
meta_data
# Out:
#           ID            Sequence    MBC  %Hemolysis
# 0    PG-1.37  HVRRLCYCRRRFCACVGS    1.0    2.600000
# 1   PG-1.20d  RGGRLRYCRRRFCVSVGR    2.0    1.607281
# 2    PG-1.62  RGGRLCYCRRRFCTCVGR    2.0    3.233927
# 3   PG-1.12A  RGGRLCYCRRRACVCVGR    2.0   12.103021
# 4   PG-1.16A  RGGRLCYCRRRFCVCAGR    2.0   15.821069
# ..       ...                 ...    ...         ...
# 88   PG-1.32  HGWRLCYCRRRFCVCVGC  100.0   35.460367
# 89   PG-1.60  RGGRLCYCRRRFCVCVGF  100.0   36.664085
# 90   PG-1.25  RGWRLCYCRRRFCVCVGH  100.0   46.397292
# 91    PG-1.7  RRWCLCFCRRRFCVCVCR  100.0   51.181276
# 92   PG-1.24  RGWRLCYCRRRFCVCVGC  100.0   78.280710
#
# [93 rows x 4 columns]

# %%
# Create the new target selectivity
meta_data['selectivity'] = meta_data['MBC'] * meta_data['%Hemolysis']
meta_data['selectivity'] = np.log10(meta_data['selectivity'])
meta_data
# Out:
#           ID            Sequence    MBC  %Hemolysis  selectivity
# 0    PG-1.37  HVRRLCYCRRRFCACVGS    1.0    2.600000     0.414973
# 1   PG-1.20d  RGGRLRYCRRRFCVSVGR    2.0    1.607281     0.507122
# 2    PG-1.62  RGGRLCYCRRRFCTCVGR    2.0    3.233927     0.810760
# 3   PG-1.12A  RGGRLCYCRRRACVCVGR    2.0   12.103021     1.383924
# 4   PG-1.16A  RGGRLCYCRRRFCVCAGR    2.0   15.821069     1.500266
# ..       ...                 ...    ...         ...          ...
# 88   PG-1.32  HGWRLCYCRRRFCVCVGC  100.0   35.460367     3.549743
# 89   PG-1.60  RGGRLCYCRRRFCVCVGF  100.0   36.664085     3.564241
# 90   PG-1.25  RGWRLCYCRRRFCVCVGH  100.0   46.397292     3.666493
# 91    PG-1.7  RRWCLCFCRRRFCVCVCR  100.0   51.181276     3.709111
# 92   PG-1.24  RGWRLCYCRRRFCVCVGC  100.0   78.280710     3.893655
#
# [93 rows x 5 columns]

# %%
# target distribuition
sns.histplot(data=meta_data, x='selectivity', bins=10, kde=True, stat='percent')
plt.show()

# %% [markdown]
# ## Embedding Extraction
#
# The embeddings I used for the model were computed using the ESM-2 15B model and I used the mean of the last layer as the embedding.
#
# Here's how to exytract them using the pre-trained model from esm2.
#
# Download the python file extract from [esm2-github](https://github.com/facebookresearch/esm), and make sure to have a conda enviromment seted up accordinly.
#
# Then run:
# python extract.py esm2_t48_15B_UR50D data/Cumulative_Peptide_data_PG1.fasta data/embedding/esm2_15B_PG1 --repr_layers 48 --include mean

# %%
# # creates a empty dictionary, and updates it with the embedds
dir_path = 'data/embedding/esm2_15B_PG1/'

embeddings = {}
for file in os.listdir(dir_path):
    file_path = str(dir_path) + file 
    label = file.split('.pt')[0]
    embeddings[label] = np.array(torch.load(file_path)['mean_representations'][48])

# here I creating a dictionary with ID as key and semantic value as value 
df = meta_data.merge(pd.DataFrame.from_dict(embeddings, orient='index'), how='inner', left_on='ID', right_index=True)
df
# Out:
#           ID            Sequence    MBC  %Hemolysis  selectivity         0  \
# 0    PG-1.37  HVRRLCYCRRRFCACVGS    1.0    2.600000     0.414973  0.056671
# 1   PG-1.20d  RGGRLRYCRRRFCVSVGR    2.0    1.607281     0.507122  0.133009
# 2    PG-1.62  RGGRLCYCRRRFCTCVGR    2.0    3.233927     0.810760  0.155696
# 3   PG-1.12A  RGGRLCYCRRRACVCVGR    2.0   12.103021     1.383924  0.056310
# 4   PG-1.16A  RGGRLCYCRRRFCVCAGR    2.0   15.821069     1.500266  0.122564
# ..       ...                 ...    ...         ...          ...       ...
# 88   PG-1.32  HGWRLCYCRRRFCVCVGC  100.0   35.460367     3.549743  0.007245
# 89   PG-1.60  RGGRLCYCRRRFCVCVGF  100.0   36.664085     3.564241  0.143025
# 90   PG-1.25  RGWRLCYCRRRFCVCVGH  100.0   46.397292     3.666493  0.068697
# 91    PG-1.7  RRWCLCFCRRRFCVCVCR  100.0   51.181276     3.709111  0.066839
# 92   PG-1.24  RGWRLCYCRRRFCVCVGC  100.0   78.280710     3.893655  0.069902
#
#            1         2         3         4  ...      5110      5111      5112  \
# 0  -0.074099 -0.040746  0.217794 -0.197767  ... -0.130863 -0.107892  0.140624
# 1  -0.124348 -0.109747  0.222604 -0.261453  ... -0.105108 -0.053451  0.092585
# 2  -0.016959 -0.179328  0.153639 -0.241203  ... -0.160722 -0.136943  0.049061
# 3  -0.137829 -0.098538  0.162526 -0.252675  ... -0.124351 -0.181434  0.037783
# 4  -0.024471 -0.127546  0.165324 -0.258667  ... -0.155189 -0.155856  0.061196
# ..       ...       ...       ...       ...  ...       ...       ...       ...
# 88 -0.115889 -0.040796  0.235570 -0.216340  ... -0.166121 -0.146094  0.080064
# 89 -0.030791 -0.110694  0.109217 -0.223111  ... -0.119124 -0.189840 -0.030339
# 90 -0.038422 -0.142241  0.184863 -0.232976  ... -0.180917 -0.172996  0.046710
# 91 -0.037917 -0.087912  0.137855 -0.218455  ... -0.167717 -0.251613 -0.086687
# 92 -0.039020 -0.122685  0.183626 -0.228307  ... -0.200931 -0.165114  0.059687
#
#         5113      5114      5115      5116      5117      5118      5119
# 0  -0.169443  0.165775 -0.120193  0.094954 -0.000617 -0.199790  0.001056
# 1  -0.201894  0.094672 -0.104331  0.135752  0.036512 -0.230271  0.020399
# 2  -0.175572  0.109034 -0.239965 -0.050614 -0.096664 -0.249927  0.020688
# 3  -0.201551  0.092573 -0.168867  0.078524 -0.003103 -0.212419  0.049512
# 4  -0.220575  0.092058 -0.220014  0.025014 -0.053914 -0.198191  0.036471
# ..       ...       ...       ...       ...       ...       ...       ...
# 88 -0.143502  0.155125 -0.067742  0.087349 -0.027154 -0.214921  0.023557
# 89 -0.218860  0.098898 -0.174355  0.023488 -0.059298 -0.252023  0.029996
# 90 -0.179037  0.106190 -0.103997 -0.029128  0.000693 -0.243295  0.019351
# 91 -0.231941  0.015133 -0.017062  0.048716 -0.028251 -0.203544 -0.114390
# 92 -0.133821  0.111872 -0.142763 -0.034693 -0.022357 -0.249541  0.047750
#
# [93 rows x 5125 columns]

# %%
# Define target and features
target = df["selectivity"]

# define features
features = df.iloc[:,meta_data.shape[1]:]
features
# Out:
#         0         1         2         3         4         5         6     \
# 0   0.056671 -0.074099 -0.040746  0.217794 -0.197767  0.223628 -0.119524
# 1   0.133009 -0.124348 -0.109747  0.222604 -0.261453  0.138052 -0.132696
# 2   0.155696 -0.016959 -0.179328  0.153639 -0.241203  0.130882 -0.101294
# 3   0.056310 -0.137829 -0.098538  0.162526 -0.252675  0.163847 -0.120923
# 4   0.122564 -0.024471 -0.127546  0.165324 -0.258667  0.142153 -0.093198
# ..       ...       ...       ...       ...       ...       ...       ...
# 88  0.007245 -0.115889 -0.040796  0.235570 -0.216340  0.226666 -0.117476
# 89  0.143025 -0.030791 -0.110694  0.109217 -0.223111  0.105739 -0.079077
# 90  0.068697 -0.038422 -0.142241  0.184863 -0.232976  0.162749 -0.080665
# 91  0.066839 -0.037917 -0.087912  0.137855 -0.218455  0.279858 -0.059348
# 92  0.069902 -0.039020 -0.122685  0.183626 -0.228307  0.150014 -0.113110
#
#         7         8         9     ...      5110      5111      5112      5113  \
# 0   0.080779 -0.021853  0.285255  ... -0.130863 -0.107892  0.140624 -0.169443
# 1   0.162016 -0.073308  0.382890  ... -0.105108 -0.053451  0.092585 -0.201894
# 2   0.178330 -0.043959  0.144877  ... -0.160722 -0.136943  0.049061 -0.175572
# 3   0.205509 -0.078092  0.267088  ... -0.124351 -0.181434  0.037783 -0.201551
# 4   0.185513 -0.060469  0.173319  ... -0.155189 -0.155856  0.061196 -0.220575
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 88  0.136838 -0.047453  0.286242  ... -0.166121 -0.146094  0.080064 -0.143502
# 89  0.181002 -0.031332  0.150899  ... -0.119124 -0.189840 -0.030339 -0.218860
# 90  0.120402 -0.020260  0.204635  ... -0.180917 -0.172996  0.046710 -0.179037
# 91  0.068789  0.069967  0.299982  ... -0.167717 -0.251613 -0.086687 -0.231941
# 92  0.142315 -0.034828  0.243144  ... -0.200931 -0.165114  0.059687 -0.133821
#
#         5114      5115      5116      5117      5118      5119
# 0   0.165775 -0.120193  0.094954 -0.000617 -0.199790  0.001056
# 1   0.094672 -0.104331  0.135752  0.036512 -0.230271  0.020399
# 2   0.109034 -0.239965 -0.050614 -0.096664 -0.249927  0.020688
# 3   0.092573 -0.168867  0.078524 -0.003103 -0.212419  0.049512
# 4   0.092058 -0.220014  0.025014 -0.053914 -0.198191  0.036471
# ..       ...       ...       ...       ...       ...       ...
# 88  0.155125 -0.067742  0.087349 -0.027154 -0.214921  0.023557
# 89  0.098898 -0.174355  0.023488 -0.059298 -0.252023  0.029996
# 90  0.106190 -0.103997 -0.029128  0.000693 -0.243295  0.019351
# 91  0.015133 -0.017062  0.048716 -0.028251 -0.203544 -0.114390
# 92  0.111872 -0.142763 -0.034693 -0.022357 -0.249541  0.047750
#
# [93 rows x 5120 columns]

# %% [markdown]
# ## Split data into train and test sets

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# ## Running Regression Models

# %%
pcas = [10, 15, 20, 25, 30, 35, 40]

results_final = pd.DataFrame()
results_cv_final = pd.DataFrame()

# Instantiate LeavePOut cross-validator 
loo = LeaveOneOut()  

for num_pca in pcas:

    pca = PCA(num_pca)
    pca.fit(X_train)

    X_train_pca = pca.transform(X_train)
    X_test_pca = pca.transform(X_test)
    
    # store the results
    results = pd.DataFrame()
    results_cv = pd.DataFrame()

    # Create a list of models to test
    models = [Lasso(), SVR()]

    # Create a dictionary of hyperparameters for each model
    param_grid = [
        # Lasso
        {'alpha': np.arange(0.01, 1, 0.01),'max_iter': [100000]},
        # SVR
        {'C': [0.1, 1, 10], 'kernel': ['linear'], 'gamma': ['scale', 0.1, 0.01, 0.001]},
        ]
    
    
    # Iterate over the models and fit and predict using grid search
    for model, param_grid in zip(models, param_grid):

        # search best hyperparameter 
        grid_search = GridSearchCV(model, param_grid, scoring='r2', cv=10, n_jobs=25)

        # train in the whole training set
        grid_search.fit(X_train_pca, y_train)

        # k-fold cross-validation on the training set
        r2_cv_scores = cross_val_score(grid_search, X_train_pca, y_train, cv=10, scoring='r2', n_jobs=25)
        mae_cv_scores = cross_val_score(grid_search, X_train_pca, y_train, cv=10, scoring='neg_mean_absolute_error', n_jobs=25)

        # make predictions
        train_pred = grid_search.predict(X_train_pca)
        y_pred = grid_search.predict(X_test_pca)

        # Model evaluation on test data
        train_r2 = metrics.r2_score(y_train, train_pred)
        train_mae = metrics.mean_absolute_error(y_train, train_pred)
        train_mse = metrics.mean_squared_error(y_train, train_pred)
        train_rmse = np.sqrt(train_mse)

        # Model evaluation on test data
        test_r2 = metrics.r2_score(y_test, y_pred)
        test_mae = metrics.mean_absolute_error(y_test, y_pred)
        test_mse = metrics.mean_squared_error(y_test, y_pred)
        test_rmse = np.sqrt(test_mse)

        model_name = grid_search.best_estimator_.__class__.__name__
        embed_name = dir_path.split('/')[-2]
        best_params = str(grid_search.best_params_)

        # print best scores
        print(f"Model: {model_name}, PCA: {num_pca}, Train R2:{train_r2:.2f}, Test R2:{test_r2:.2f}, best params {best_params}")
        print("R2 CV Scores:", r2_cv_scores)
        print()

        # Saving results
        res_dict = {}
        res_dict["Embedding"] = embed_name
        res_dict["model"] = model_name
        res_dict["num_pca"] = num_pca
        res_dict["Train_R2_score"] = train_r2.round(2)
        res_dict["Train_MAE_score"] = train_mae.round(2)
        res_dict["Train_RMSE_score"] = train_rmse.round(2)

        # test scores
        res_dict["Test_R2_score"] = test_r2.round(2)
        res_dict["Test_MAE_score"] = test_mae.round(2)
        res_dict["Test_RMSE_score"] = test_rmse.round(2)
        res_dict["Test_Best_params"] = best_params

        # updating data frame with results
        results = pd.concat([results, pd.DataFrame(res_dict, index=[0])]).reset_index(drop=True)

        #save results from cross-validation
        res_cv_dict = {
            "model": [model_name for i in range(len(mae_cv_scores))],
            "num_pca": [num_pca for i in range(len(mae_cv_scores))],
            "r2_CV_scores": r2_cv_scores,
            "Mae_CV_scores": mae_cv_scores,
        }
        #updating data frame with results
        results_cv = pd.concat([results_cv, pd.DataFrame(res_cv_dict)]).reset_index(drop=True)

    
    results_final = pd.concat([results_final, results]).reset_index(drop=True)
    results_cv_final = pd.concat([results_cv_final, results_cv]).reset_index(drop=True)

# save results
#results_final.to_excel('results/results_regression_selectivity_v02.xlsx')
#results_cv_final.to_excel('results/results_cv_regression_selectivity_v02.xlsx')
# Out:
# Model: Lasso, PCA: 10, Train R2:0.70, Test R2:0.39, best params {'alpha': 0.03, 'max_iter': 100000}
# R2 CV Scores: [0.59486436 0.59747756 0.59173228 0.70847221 0.45296787 0.24423711
#  0.08173444 0.66038204 0.40777863 0.40015047]
#
# Model: SVR, PCA: 10, Train R2:0.72, Test R2:0.38, best params {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# R2 CV Scores: [0.67100482 0.59897804 0.45713505 0.79065261 0.56874652 0.4205358
#  0.33937803 0.73327618 0.35931135 0.44385726]
#
# Model: Lasso, PCA: 15, Train R2:0.79, Test R2:0.61, best params {'alpha': 0.02, 'max_iter': 100000}
# R2 CV Scores: [0.76017796 0.69234783 0.51873825 0.71319848 0.52171245 0.50028444
#  0.64131079 0.83207616 0.462041   0.24371672]
#
# Model: SVR, PCA: 15, Train R2:0.80, Test R2:0.64, best params {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# R2 CV Scores: [0.79083061 0.69741266 0.53324881 0.77018843 0.65842081 0.66468546
#  0.48634512 0.8735169  0.46067425 0.22685178]
#
# Model: Lasso, PCA: 20, Train R2:0.84, Test R2:0.64, best params {'alpha': 0.01, 'max_iter': 100000}
# R2 CV Scores: [0.77573985 0.71377012 0.55808966 0.7153109  0.67589526 0.55372059
#  0.1959536  0.87652631 0.48119777 0.34781265]
#
# Model: SVR, PCA: 20, Train R2:0.83, Test R2:0.62, best params {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# R2 CV Scores: [ 0.7680427   0.73571088  0.65379564  0.7205738   0.72194159  0.59605733
#  -0.36648618  0.82221223  0.53588058  0.4665507 ]
#
# Model: Lasso, PCA: 25, Train R2:0.80, Test R2:0.58, best params {'alpha': 0.02, 'max_iter': 100000}
# R2 CV Scores: [0.77574817 0.71390393 0.55860289 0.71556148 0.63332091 0.5532274
#  0.19996458 0.84476723 0.48130411 0.34934764]
#
# Model: SVR, PCA: 25, Train R2:0.84, Test R2:0.61, best params {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# R2 CV Scores: [0.76211754 0.75575021 0.68024056 0.73230986 0.66237623 0.49794007
#  0.51642081 0.83048145 0.50044974 0.4884489 ]
#
# Model: Lasso, PCA: 30, Train R2:0.80, Test R2:0.58, best params {'alpha': 0.02, 'max_iter': 100000}
# R2 CV Scores: [ 0.78746958  0.71387568  0.5585328   0.71553185  0.58001906  0.55330931
#   0.23959179  0.84471533  0.48129242 -0.06312282]
#
# Model: SVR, PCA: 30, Train R2:0.85, Test R2:0.58, best params {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# R2 CV Scores: [0.80406457 0.79157279 0.75070362 0.72447619 0.5739767  0.52049332
#  0.6119747  0.79245647 0.50806453 0.48771747]
#
# Model: Lasso, PCA: 35, Train R2:0.80, Test R2:0.58, best params {'alpha': 0.02, 'max_iter': 100000}
# R2 CV Scores: [ 0.78698874  0.71389237  0.5585526   0.71552597  0.55531685  0.55328409
#   0.24289307  0.8447159   0.48131445 -0.0519841 ]
#
# Model: SVR, PCA: 35, Train R2:0.86, Test R2:0.61, best params {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# R2 CV Scores: [0.83549527 0.79305176 0.79212875 0.74079999 0.61434954 0.50974677
#  0.68483388 0.6763097  0.53342415 0.49791791]
#
# Model: Lasso, PCA: 40, Train R2:0.80, Test R2:0.58, best params {'alpha': 0.02, 'max_iter': 100000}
# R2 CV Scores: [0.81331303 0.77622909 0.55853608 0.71553439 0.63505907 0.5532641
#  0.35229112 0.84471077 0.55231561 0.09329793]
#
# Model: SVR, PCA: 40, Train R2:0.88, Test R2:0.61, best params {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# R2 CV Scores: [0.86029549 0.81588288 0.79570066 0.80222225 0.64916446 0.65712926
#  0.75990255 0.7939104  0.53389465 0.58183331]

# %% [markdown]
# ## Results Visualization

# %% [markdown]
# ### MAE across the validation sets

# %%
#results_cv_final = pd.read_excel('results/results_cv_regression_selectivity_v02.xlsx', index_col=0)
sns.boxplot(data=results_cv_final, x='num_pca', y='Mae_CV_scores', hue='model' , showfliers=False)
plt.title('Cross-validation MAE scores')
plt.show()

# %% [markdown]
# ## R2 across the validation sets

# %%
sns.boxplot(data=results_cv_final, x='num_pca', y='r2_CV_scores', hue='model' , showfliers=False)
plt.title('Cross-validation R2 scores')
plt.ylim(-1, 1)
plt.show()

# %%
#results_final = pd.read_excel('results/results_regression_selectivity_v02.xlsx', index_col=0)
results_final
# Out:
#        Embedding  model  num_pca  Train_R2_score  Train_MAE_score  \
# 0   esm2_15B_PG1  Lasso       10            0.70             0.34
# 1   esm2_15B_PG1    SVR       10            0.72             0.31
# 2   esm2_15B_PG1  Lasso       15            0.79             0.28
# 3   esm2_15B_PG1    SVR       15            0.80             0.26
# 4   esm2_15B_PG1  Lasso       20            0.84             0.24
# 5   esm2_15B_PG1    SVR       20            0.83             0.24
# 6   esm2_15B_PG1  Lasso       25            0.80             0.27
# 7   esm2_15B_PG1    SVR       25            0.84             0.23
# 8   esm2_15B_PG1  Lasso       30            0.80             0.27
# 9   esm2_15B_PG1    SVR       30            0.85             0.22
# 10  esm2_15B_PG1  Lasso       35            0.80             0.27
# 11  esm2_15B_PG1    SVR       35            0.86             0.21
# 12  esm2_15B_PG1  Lasso       40            0.80             0.27
# 13  esm2_15B_PG1    SVR       40            0.88             0.19
#
#     Train_RMSE_score  Test_R2_score  Test_MAE_score  Test_RMSE_score  \
# 0               0.42           0.39            0.45             0.64
# 1               0.41           0.38            0.46             0.65
# 2               0.36           0.61            0.35             0.52
# 3               0.35           0.64            0.35             0.50
# 4               0.31           0.64            0.33             0.49
# 5               0.32           0.62            0.33             0.51
# 6               0.35           0.58            0.36             0.53
# 7               0.31           0.61            0.35             0.52
# 8               0.35           0.58            0.36             0.53
# 9               0.30           0.58            0.38             0.53
# 10              0.35           0.58            0.36             0.53
# 11              0.29           0.61            0.37             0.52
# 12              0.35           0.58            0.36             0.53
# 13              0.27           0.61            0.37             0.51
#
#                                     Test_Best_params
# 0                {'alpha': 0.03, 'max_iter': 100000}
# 1   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 2                {'alpha': 0.02, 'max_iter': 100000}
# 3   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 4                {'alpha': 0.01, 'max_iter': 100000}
# 5   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 6                {'alpha': 0.02, 'max_iter': 100000}
# 7   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 8                {'alpha': 0.02, 'max_iter': 100000}
# 9   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 10               {'alpha': 0.02, 'max_iter': 100000}
# 11  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 12               {'alpha': 0.02, 'max_iter': 100000}
# 13  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# ### Train x Test Model performances

# %%
# Reshape the dataframe to long format
melted_df = pd.melt(results_final, 
                    id_vars=['num_pca', 'model'], 
                    value_vars=['Test_R2_score', 'Train_R2_score'], 
                    var_name='Score Type', value_name='R2 Score')

# %%
# Example using FacetGrid for a categorical breakdown
g = sns.FacetGrid(melted_df, col="Score Type", sharey=False, height=5, aspect=1.2, ylim=(0,1), col_order=['Train_R2_score', 'Test_R2_score'])
g.map_dataframe(sns.barplot, x="num_pca", y="R2 Score", hue='model', palette='muted')
g.set_axis_labels("Number of PCAs", "R2 Score")
g.set_titles(col_template="{col_name}", row_template="{row_name}")
g.add_legend()
plt.show()

# %% [markdown]
# To determine if the model is overfitting, it's important to evaluate its performance on a validation set or using cross-validation.
# If the model's performance on the validation set is significantly worse than its performance on the training set, then it may be overfitting.
# In such cases, it may be necessary to adjust the hyperparameters of the model or to use a more complex kernel function.

# %% [markdown]
# ## Fine Tunning Model with best hyperparameter found with Gridsearch

# %%
results_final.query('num_pca == 20')
# Out:
#       Embedding  model  num_pca  Train_R2_score  Train_MAE_score  \
# 4  esm2_15B_PG1  Lasso       20            0.84             0.24
# 5  esm2_15B_PG1    SVR       20            0.83             0.24
#
#    Train_RMSE_score  Test_R2_score  Test_MAE_score  Test_RMSE_score  \
# 4              0.31           0.64            0.33             0.49
# 5              0.32           0.62            0.33             0.51
#
#                                    Test_Best_params
# 4               {'alpha': 0.01, 'max_iter': 100000}
# 5  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
num_pca_components = 20

pca = PCA(num_pca_components)
pca.fit(X_train)

X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %% [markdown]
# ## Lasso

# %%
lasso = Lasso(
    alpha=0.01,
    max_iter=10000    
)

# fined tuned SVR performance
lasso.fit(X_train_pca, y_train)

# print R2 score
print(f'Train R2 score: {lasso.score(X_train_pca, y_train):.2f}')
print(f'Test R2 score: {lasso.score(X_test_pca, y_test):.2f}')
# Out:
# Train R2 score: 0.84
# Test R2 score: 0.64

# %%
train_pred = lasso.predict(X_train_pca)
y_pred = lasso.predict(X_test_pca)

plt.scatter(train_pred, y_train, label="Train samples", c='#d95f02')
plt.scatter(y_pred, y_test, label="Test samples", c='#7570b3')
plt.title(f"Model: Linear Regressor")
plt.xlabel("Predicted Selectivity score")
plt.ylabel("True Selectivity score")
plt.plot([0, 6], [0, 6], c='k', zorder=0) 
plt.text(0, 5, f'Train R$^2$: {lasso.score(X_train_pca, y_train).round(2)}', fontsize = 9)
plt.text(0, 4.5, f'Test R$^2$: {lasso.score(X_test_pca, y_test).round(2)}', fontsize = 9)
plt.legend()
plt.show()

# %% [markdown]
# ## SVR

# %%
# train support vector machine regressor
svmR = SVR(
    C=0.1, 
    gamma='scale',
    kernel='linear',
    )

# fined tuned SVR performance
svmR.fit(X_train_pca, y_train)

# print R2 score
print(f'Train R2 score: {svmR.score(X_train_pca, y_train):.2f}')
print(f'Test R2 score: {svmR.score(X_test_pca, y_test):.2f}')
# Out:
# Train R2 score: 0.83
# Test R2 score: 0.62

# %%
train_pred = svmR.predict(X_train_pca)
y_pred = svmR.predict(X_test_pca)

plt.scatter(train_pred, y_train, label="Train samples", c='#d95f02')
plt.scatter(y_pred, y_test, label="Test samples", c='#7570b3')
plt.title(f"Model: Linear Regressor")
plt.xlabel("Predicted Selectivity score")
plt.ylabel("True Selectivity score")
plt.plot([0, 6], [0, 6], c='k', zorder=0) 
plt.text(0, 5, f'Train R$^2$: {svmR.score(X_train_pca, y_train).round(2)}', fontsize = 9)
plt.text(0, 4.5, f'Test R$^2$: {svmR.score(X_test_pca, y_test).round(2)}', fontsize = 9)
plt.legend()
plt.show()

# %% [markdown]
# ## Saving model and PCA weights

# %%
## save the model
joblib.dump(lasso, 'models/model_v02_svmR20_esm2_15B_selectivity_regression.pkl')
joblib.dump(pca, 'models/weights_pca20_esm2_15B_selectivity.pkl')
# Out:
# ['models/weights_pca20_esm2_15B_selectivity.pkl']

# %% [markdown]
# ## Validation

# %%
import os
import torch
import pandas as pd
import numpy as np
import pickle
import joblib

# %%
# Loading the model
model = joblib.load('models/model_v02_svmR20_esm2_15B_selectivity_regression.pkl')

# Loading PCA weights
pca = joblib.load('models/weights_pca20_esm2_15B_selectivity.pkl')

# %%
# load meta_data with mutations on PG1
meta_data = pd.read_csv('results/v01.2/predictions_validation_set_v01.2.csv')

####################### Load the embedding ######################
dir_path = 'data/embedding/esm2_15B_PG1_validation/'
embeddings = {}
for file in os.listdir(dir_path):
        file_path = str(dir_path) + file 
        label = file.split('.pt')[0]
        embeddings[label] = np.array(torch.load(file_path)['mean_representations'][48])


# here I creating a dictionary with ID as key and semantic value as value 
data = meta_data.merge(pd.DataFrame.from_dict(embeddings, orient='index'), how='inner', left_on='ID2', right_index=True)


features = data.iloc[:,meta_data.shape[1]:]
features.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.109975 -0.134590 -0.111443  0.218644 -0.237748  0.131493 -0.119502
# 1  0.129701 -0.184889 -0.115536  0.161651 -0.224050  0.112427 -0.157890
# 2  0.099468 -0.114953 -0.117187  0.183187 -0.209792  0.091260 -0.130392
# 3  0.156776 -0.105166 -0.063266  0.204592 -0.202521  0.076685 -0.140390
# 4  0.148965 -0.141826 -0.064849  0.198645 -0.237333  0.096351 -0.192772
#
#        7         8         9     ...      5110      5111      5112      5113  \
# 0  0.234007 -0.042554  0.338132  ... -0.136047 -0.087660  0.107472 -0.270478
# 1  0.269912 -0.049523  0.307800  ... -0.106790 -0.129787  0.076798 -0.208119
# 2  0.256235 -0.053187  0.229403  ... -0.195330 -0.116773  0.137988 -0.164647
# 3  0.251750 -0.082083  0.299491  ... -0.100395 -0.043842  0.144827 -0.125664
# 4  0.201036 -0.055550  0.323271  ... -0.108473 -0.066790  0.079047 -0.211575
#
#        5114      5115      5116      5117      5118      5119
# 0  0.122341 -0.089307  0.137297  0.075365 -0.198461 -0.035045
# 1  0.098149 -0.133004  0.089372  0.093026 -0.170869 -0.013929
# 2  0.119364 -0.178338  0.031593  0.029154 -0.215111 -0.017543
# 3  0.134358 -0.157067  0.040382  0.030294 -0.248444  0.020361
# 4  0.114173 -0.089037  0.146931  0.012782 -0.173229  0.016016
#
# [5 rows x 5120 columns]

# %%
# calculates the probability of being active
pred = model.predict(pca.transform(features))

sum(pred < 0.5)
# Out:
# 6

# %%
meta_data['selectivity_pred_v02'] = pred
meta_data
# Out:
#                   ID        ID2            Sequence  RGGRLCYCRRRFCVCVGR  \
# 0   PG1_3mut_1739000   bsPG-1.1  RGGRLQYCRRRFCVARGR  -----Q--------AR--
# 1   PG1_3mut_1218602   bsPG-1.2  RGGRLQYCRRRGCVTVGR  -----Q-----G--T---
# 2   PG1_3mut_1896424   bsPG-1.3  RGGRLAYCRRRDCTCVGR  -----A-----D-T----
# 3   PG1_3mut_1275003   bsPG-1.4  RGGRLDYCRRRFCVTTGR  -----D--------TT--
# 4    PG1_3mut_257802   bsPG-1.5  RGGRLQACRRRFCVTVGR  -----QA-------T---
# 5   PG1_3mut_1210489   bsPG-1.6  RGGRLRYCRRRFDVSVGR  -----R------D-S---
# 6   PG1_3mut_1536372   bsPG-1.7  RGGRLCTARRRFCVRVGR  ------TA------R---
# 7   PG1_3mut_1147726   bsPG-1.8  RGGRLTYCRRRFCTAVGR  -----T-------TA---
# 8   PG1_3mut_1980555   bsPG-1.9  RGGRLTYCRRRDCVAVGR  -----T-----D--A---
# 9   PG1_3mut_1658870  bsPG-1.10  RGGRLAYCRRRFCVDTGR  -----A--------DT--
# 10  PG1_3mut_1618529  bsPG-1.11  RGGRLRYCRRRGTVCVGR  -----R-----GT-----
# 11   PG1_3mut_720432  bsPG-1.12  RGGRLQYCRRRFCARVGR  -----Q-------AR---
# 12  PG1_3mut_1247939  bsPG-1.13  RGGRLCYCRRRNCVTTGR  -----------N--TT--
# 13  PG1_3mut_1926344  bsPG-1.14  RGGRLCTARRRFCVHVGR  ------TA------H---
# 14    PG1_3mut_70973  bsPG-1.15  RGGRLCDCRRRFCNMVGR  ------D------NM---
# 15   PG1_3mut_969074  bsPG-1.16  RGGRLQYCRRRFDTCVGR  -----Q------DT----
# 16   PG1_3mut_624778  bsPG-1.17  RGGRLCTCRRRFCASVGR  ------T------AS---
# 17  PG1_3mut_1114717  bsPG-1.18  RGGRLRYCRRRFRVSVGR  -----R------R-S---
# 18   PG1_3mut_902003  bsPG-1.19  RGGRLEYCRRRFCVNTGR  -----E--------NT--
# 19   PG1_3mut_484549  bsPG-1.20  RGGRLTYCRRRFCADVGR  -----T-------AD---
# 20   PG1_3mut_789807  bsPG-1.21  RGGRLCYRRRRTAVCVGR  -------R---TA-----
# 21  PG1_3mut_1838343  bsPG-1.22  RGGRLCYCRRRFCTPVTR  -------------TP-T-
# 22   PG1_3mut_945905  bsPG-1.23  RTGRLCYCRRRDCTCVGR  -T---------D-T----
# 23    PG1_3mut_26231  bsPG-1.24  RGGRLHYRRRRFCVRVGR  -----H-R------R---
# 24   PG1_3mut_485919  bsPG-1.25  RGGRPCYCRRRFCGTVGR  ----P--------GT---
# 25   PG1_3mut_437553  bsPG-1.26  RGGRLCDCRRRTCRCVGR  ------D----T-R----
# 26   PG1_3mut_840730  bsPG-1.27  RGGRDIYCRRRFCVTVGR  ----DI--------T---
# 27  PG1_3mut_1102178  bsPG-1.28  RGGRLCYCRRRTCVDTGR  -----------T--DT--
# 28   PG1_3mut_939583  bsPG-1.29  RGGRLCYSRRRFCKTVGR  -------S-----KT---
# 29   PG1_3mut_439660  bsPG-1.30  RGGRLAYCRRRFCVAVAR  -----A--------A-A-
# 30   PG1_3mut_341044  bsPG-1.31  RGGRLCYGRRRFCVNQGR  -------G------NQ--
# 31  PG1_3mut_1166571  bsPG-1.32  RGGRSCHCRRRFCVIVGR  ----S-H-------I---
# 32  PG1_3mut_1080117  bsPG-1.33  RGRRACYCRRRFCVHVGR  --R-A---------H---
# 33   PG1_3mut_261082  bsPG-1.34  RGGRLSYCRRRFCVAGGR  -----S--------AG--
# 34   PG1_3mut_881885  bsPG-1.35  RGQRLCYCRRRFNVCTGR  --Q---------N--T--
# 35   PG1_3mut_702701  bsPG-1.36  RGGRLCYCRRRFCAVNGR  -------------AVN--
#
#     Select    Charge    group MIC MH      %hemo  L10Select  \
# 0    -0.82  6.742145   <-0.25     16   0.428850   0.836425
# 1    -0.76  5.742155   <-0.25      4   0.341131   0.134981
# 2    -0.65  4.651497       CP    >64  -0.165692        NaN
# 3    -0.56  4.742406   <-0.25     64   0.165692   1.025482
# 4    -0.44  5.744660   <-0.25      8   0.721248   0.761174
# 5    -0.43  5.833305   <-0.25     16   0.735867   1.070920
# 6    -0.43  6.744650   <-0.25      2   0.906433   0.258366
# 7    -0.40  5.742155   <-0.25     16   0.043860  -0.153815
# 8    -0.29  4.742406   <-0.25     32   0.116959   0.573184
# 9    -0.28  4.742406   <-0.25     64   0.092593   0.772756
# 10   -0.28  6.742145       CP    >64   0.268031        NaN
# 11   -0.27  6.742145   <-0.25     16   0.141326   0.354341
# 12   -0.25  5.651245  -0.25-0    >64  -0.058480        NaN
# 13   -0.22  5.835569  -0.25-0     16   0.638402   1.009214
# 14   -0.15  4.654002  -0.25-0    >64  -0.097466        NaN
# 15   -0.14  4.742406  -0.25-0    >64   0.034113        NaN
# 16   -0.14  5.653751  -0.25-0     32   0.487329   1.192973
# 17   -0.13  7.833044  -0.25-0     16   1.525341   1.387487
# 18   -0.13  4.742552  -0.25-0    >64   1.281676        NaN
# 19   -0.10  4.742406  -0.25-0     64   0.248538   1.201573
# 20   -0.10  6.742145       CP      8   0.404483   0.509991
# 21   -0.03  5.651245  -0.25-0     64   0.389864   1.397093
# 22   -0.02  4.560587       CP     32   0.053606   0.234365
# 23   -0.01  7.923953  -0.25-0      8   9.722222   1.890856
# 24    0.03  5.651245    0-0.5    >64  -0.009747        NaN
# 25    0.04  5.563083       CP    >64   0.194932        NaN
# 26    0.10  4.742406    0-0.5      8   0.662768   0.724452
# 27    0.17  4.651497    0-0.5     32   0.160819   0.711487
# 28    0.33  6.741654    0-0.5     64   0.560429   1.554700
# 29    0.36  5.742155    0-0.5      2   1.076998   0.333245
# 30    0.37  5.742155    0-0.5     32   2.061404   1.819313
# 31    0.37  5.744660    0-0.5      4  15.696881   1.797873
# 32    0.38  6.742145    0-0.5      4   3.664717   1.166100
# 33    0.40  5.742155    0-0.5     16   0.321637   0.711487
# 34    0.41  5.651245       CP     32   0.399610   1.106786
# 35    0.45  5.651245    0-0.5     64   0.116959   0.874214
#
#     hemolysis_pred_v01.2  selectivity_pred_v01.2  activity_pred_v01.2  \
# 0              -7.675692               -0.987362                100.0
# 1             -14.298704               -1.215473                100.0
# 2             -14.385390               -1.305665                100.0
# 3             -19.078636               -0.686002                100.0
# 4              -3.053714               -0.247956                100.0
# 5             -13.542688               -0.695068                100.0
# 6              -3.345207               -0.416047                100.0
# 7             -12.337255               -0.839417                100.0
# 8             -21.809423               -0.699560                100.0
# 9              -9.999792               -0.342884                100.0
# 10             -5.660681               -0.654460                100.0
# 11             -2.912143               -0.348571                100.0
# 12            -14.079775               -0.478759                100.0
# 13             -1.718951               -0.199801                100.0
# 14             -8.957634                0.108545                100.0
# 15            -15.366731               -1.027213                100.0
# 16              0.506438               -0.073250                100.0
# 17              0.554981               -0.397154                100.0
# 18            -10.515178               -0.187527                100.0
# 19            -15.554958               -0.281757                100.0
# 20             -9.616057               -0.224147                100.0
# 21             -6.641514               -0.214472                100.0
# 22             -8.263932               -0.334165                100.0
# 23             -9.540926                0.028367                100.0
# 24             -0.994274               -0.381789                100.0
# 25             -6.507852               -0.163775                100.0
# 26             -9.883299                0.118627                100.0
# 27            -11.357187               -0.072031                100.0
# 28              1.551211                0.101647                100.0
# 29             -1.721362                0.664414                100.0
# 30             -1.774004               -0.034093                100.0
# 31             -2.584238                0.779326                100.0
# 32             -0.897124                0.549621                100.0
# 33              0.575238                0.464198                100.0
# 34             -2.725072               -0.036225                100.0
# 35             -6.823680                0.701898                100.0
#
#     hemolysis_pred_v02  selectivity_pred_v02  activity_pred_v02
# 0            -4.054558              0.448899              92.34
# 1            -6.763184              0.368799              88.34
# 2            -8.310135              0.390410              95.37
# 3            -2.867607              0.552553              90.87
# 4            -3.139629              0.636513              94.94
# 5            -2.812324              0.449201              90.10
# 6            -3.347273              0.609653              94.73
# 7            -1.988224              0.644135              98.64
# 8           -13.069695              0.206361              93.60
# 9            -5.106495              0.504043              93.70
# 10           -1.498447              0.631221              83.26
# 11           -4.230751              0.461692              90.30
# 12           -1.894340              0.659782              92.81
# 13           -2.905787              0.783185              87.66
# 14           -7.735706              0.545411              68.43
# 15           -2.670889              0.618732              91.49
# 16           -2.594505              0.872689              98.31
# 17            3.938261              0.569385              95.43
# 18           -1.731125              0.642734              80.77
# 19           -5.932812              0.547104              95.17
# 20           -7.072010              0.671800              77.76
# 21           -2.631250              1.082659              84.77
# 22           -2.657715              0.792874              50.85
# 23            2.111896              0.786185              91.49
# 24           -0.263622              0.893200              95.69
# 25           -3.961687              0.685757               0.49
# 26            0.154079              0.956514               7.18
# 27           -2.748653              0.853561              88.73
# 28            2.327160              0.850030              97.39
# 29           -5.520584              0.812613              96.13
# 30           -1.552879              0.679024              93.17
# 31            0.003508              1.037089              67.97
# 32            2.614080              1.044137              84.35
# 33           -0.155737              0.879992              96.83
# 34            4.564720              1.079400              64.24
# 35           -4.328007              0.761783              85.33

# %%
meta_data.to_csv('results/v01.2/predictions_validation_set_v01.2.csv', index=False)
